# %%
import pandas as pd

workshoplist = pd.read_csv("Workshop_Liste_SW.csv")

workshop = pd.read_csv("Workshop_Übersicht_E.csv")

# %%
workshops_final = pd.merge(workshop, workshoplist, on=['Workshopname', 'URL_E'], how='inner')

# %%
workshops_final
# Out:
#                                           Workshopname    Kategorie  \
# 0        Burlesque mit Hurricane Irina: All things Boa    Burlesque
# 1    Love on Heels - High Heel Walk & Selbstbewusst...       Tanzen
# 2    Pole Dance Oster Special mit Gem ab Mittelstuf...    Poledance
# 3    Pole Dance Oster Special mit Gem für Fortgesch...    Poledance
# 4                           Burlesque mit Harpy Fatale    Burlesque
# ..                                                 ...          ...
# 152                                   Intro to Hammock  Aerial Hoop
# 153                                        Aerial Hoop  Aerial Hoop
# 154                    Favourit Pole Combos and Splitz    Poledance
# 155                                        Pole Choreo    Poledance
# 156                             Spinning an der Static    Polesport
#
#                                   Datum  Land  \
# 0                Sonntag, 17. März 2024   NaN
# 1                Samstag, 23. März 2024   NaN
# ...

# %%
workshops_final.to_excel("workshops_final.xlsx")
